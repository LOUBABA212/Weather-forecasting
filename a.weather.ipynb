# %%
import pandas as pd

# %% [markdown]
# Loading data

# %%
weather = pd.read_csv(r"C:\Users\HP\Downloads\3479292.csv",index_col="DATE")

# %%
weather
# Out:
#                 STATION                                            NAME  ACMH  \
# DATE
# 1960-04-01  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-02  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-03  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-04  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 1960-04-05  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# ...                 ...                                             ...   ...
# 2023-09-28  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 2023-09-29  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 2023-09-30  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 2023-10-01  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
# 2023-10-02  USW00093738  WASHINGTON DULLES INTERNATIONAL AIRPORT, VA US   NaN
#
# ...

# %% [markdown]
# Counting null values

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.495344
# ACSH       0.495212
# AWND       0.359560
# FMTM       0.554080
# FRGT       0.999956
# PGTM       0.258859
# PRCP       0.004766
# PSUN       0.999912
# SNOW       0.002427
# SNWD       0.004634
# TAVG       0.712987
# TMAX       0.001986
# TMIN       0.002074
# TSUN       0.957769
# WDF1       0.495344
# WDF2       0.558360
# WDF5       0.561140
# WDFG       0.469176
# WESD       0.723490
# WSF1       0.495300
# WSF2       0.558360
# WSF5       0.561096
# WSFG       0.469176
# WT01       0.548740
# WT02       0.937337
# WT03       0.917347
# WT04       0.982393
# WT05       0.982393
# WT06       0.986497
# WT07       0.995058
# WT08       0.781872
# WT09       0.996117
# WT10       0.999868
# WT11       0.998985
# WT13       0.877322
# WT14       0.961785
# WT15       0.997088
# WT16       0.669609
# WT17       0.995322
# WT18       0.949384
# WT19       0.999426
# WT21       0.991836
# WT22       0.997220
# ...

# %% [markdown]
# Create dataframe

# %%
core_weather = weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy()

# %%
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-04-01    0.03   0.0         0.0      71.0      47.0
# 1960-04-02    1.36   0.0         0.0       NaN       NaN
# 1960-04-03     NaN   0.0         0.0       NaN       NaN
# 1960-04-04     NaN   0.0         0.0      70.0       NaN
# 1960-04-05    1.75   0.0         0.0      48.0      42.0
# ...            ...   ...         ...       ...       ...
# 2023-09-28    0.03   0.0         0.0      72.0      51.0
# 2023-09-29    0.01   0.0         0.0      69.0      61.0
# 2023-09-30    0.00   0.0         0.0      80.0      59.0
# 2023-10-01    0.00   0.0         0.0      83.0      56.0
# 2023-10-02     NaN   NaN         NaN       NaN       NaN
#
# [22661 rows x 5 columns]

# %% [markdown]
# Cleaning Data

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip        0.004766
# snow          0.002427
# snow_depth    0.004634
# temp_max      0.001986
# temp_min      0.002074
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# snow
# 0.0     21976
# 0.2        69
# 0.3        48
# 0.1        45
# 0.4        32
#         ...
# 11.4        1
# 10.5        1
# 8.3         1
# 9.1         1
# 7.7         1
# Name: count, Length: 92, dtype: int64

# %%
core_weather[pd.isnull(core_weather["snow"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1961-12-01     NaN   NaN         NaN      51.0      25.0
# 1961-12-02     NaN   NaN         NaN      53.0      28.0
# 1961-12-03     NaN   NaN         NaN      53.0      25.0
# 1961-12-04     NaN   NaN         NaN      55.0      30.0
# 1961-12-05     NaN   NaN         NaN      46.0      19.0
# 1961-12-06     NaN   NaN         NaN      50.0      20.0
# 1961-12-07     NaN   NaN         NaN      48.0      16.0
# 1961-12-08     NaN   NaN         NaN      39.0      18.0
# 1961-12-09     NaN   NaN         NaN      31.0      13.0
# 1961-12-10     NaN   NaN         NaN      43.0      29.0
# 1961-12-11     NaN   NaN         NaN      43.0      29.0
# 1961-12-12     NaN   NaN         NaN      39.0      35.0
# 1961-12-13     NaN   NaN         NaN      40.0      20.0
# 1961-12-14     NaN   NaN         NaN      31.0      10.0
# 1961-12-15     NaN   NaN         NaN      34.0      15.0
# ...

# %%
core_weather["snow"]= core_weather["snow"].fillna(0)

# %%
core_weather["snow_depth"].value_counts()
# Out:
# snow_depth
# 0.0     21538
# 1.0       242
# 2.0       190
# 3.0       146
# 4.0        95
# 5.0        56
# 6.0        47
# 1.2        43
# 7.0        28
# 8.0        27
# 3.1        19
# 9.0        18
# 3.9        13
# 10.0       11
# 15.0        9
# 18.0        8
# 12.0        8
# 5.1         7
# 11.0        6
# 20.0        4
# 5.9         4
# 7.1         4
# 13.0        3
# 14.0        3
# 7.9         3
# 16.0        3
# 21.0        3
# 19.0        3
# 24.0        2
# 22.0        2
# 17.0        1
# 25.0        1
# 26.0        1
# 23.0        1
# 28.0        1
# 27.2        1
# 25.2        1
# 18.1        1
# 16.1        1
# 14.2        1
# 9.8         1
# Name: count, dtype: int64

# %%
core_weather[pd.isnull(core_weather["snow_depth"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1961-12-01     NaN   0.0         NaN      51.0      25.0
# 1961-12-02     NaN   0.0         NaN      53.0      28.0
# 1961-12-03     NaN   0.0         NaN      53.0      25.0
# 1961-12-04     NaN   0.0         NaN      55.0      30.0
# 1961-12-05     NaN   0.0         NaN      46.0      19.0
# ...            ...   ...         ...       ...       ...
# 2023-08-26    0.00   0.0         NaN      94.0      74.0
# 2023-08-29    0.01   0.0         NaN      82.0      72.0
# 2023-08-30    0.00   0.0         NaN      89.0      70.0
# 2023-09-12    0.81   0.0         NaN      91.0      65.0
# 2023-10-02     NaN   0.0         NaN       NaN       NaN
#
# [105 rows x 5 columns]

# %%
core_weather["snow_depth"]= core_weather["snow_depth"].fillna(0)

# %%
core_weather["precip"].value_counts()
# Out:
# precip
# 0.00    15286
# 0.01      743
# 0.02      453
# 0.03      344
# 0.04      295
#         ...
# 2.61        1
# 2.11        1
# 2.13        1
# 3.56        1
# 2.18        1
# Name: count, Length: 277, dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-04-03     NaN   0.0         0.0       NaN       NaN
# 1960-04-04     NaN   0.0         0.0      70.0       NaN
# 1960-04-22     NaN   0.0         0.0       NaN       NaN
# 1960-05-01     NaN   0.0         0.0       NaN       NaN
# 1960-05-09     NaN   0.0         0.0      66.0      45.0
# ...            ...   ...         ...       ...       ...
# 1963-02-22     NaN   0.0         0.0      21.0       8.0
# 1963-02-23     NaN   0.0         0.0      34.0       5.0
# 1963-02-24     NaN   0.0         0.0      38.0      29.0
# 1963-02-25     NaN   0.0         0.0      47.0      19.0
# 2023-10-02     NaN   0.0         0.0       NaN       NaN
#
# [108 rows x 5 columns]

# %%
core_weather["precip"]= core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip        0.000000
# snow          0.000000
# snow_depth    0.000000
# temp_max      0.001986
# temp_min      0.002074
# dtype: float64

# %%
core_weather["temp_max"].value_counts()
# Out:
# temp_max
# 85.0     542
# 83.0     534
# 84.0     533
# 80.0     518
# 87.0     511
#         ...
# 13.0       1
# 11.0       1
# 10.0       1
# 6.0        1
# 105.0      1
# Name: count, Length: 98, dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_max"])]
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-04-02    1.36   0.0         0.0       NaN       NaN
# 1960-04-03    0.00   0.0         0.0       NaN       NaN
# 1960-04-09    0.00   0.0         0.0       NaN       NaN
# 1960-04-10    0.00   0.0         0.0       NaN       NaN
# 1960-04-16    0.00   0.0         0.0       NaN       NaN
# 1960-04-17    0.00   0.0         0.0       NaN       NaN
# 1960-04-22    0.00   0.0         0.0       NaN       NaN
# 1960-04-23    0.00   0.0         0.0       NaN       NaN
# 1960-04-24    0.00   0.0         0.0       NaN       NaN
# 1960-04-30    0.26   0.0         0.0       NaN       NaN
# 1960-05-01    0.00   0.0         0.0       NaN       NaN
# 1960-05-07    0.00   0.0         0.0       NaN       NaN
# 1960-05-14    0.00   0.0         0.0       NaN       NaN
# 1960-05-15    0.00   0.0         0.0       NaN       NaN
# 1960-05-20    0.00   0.0         0.0       NaN       NaN
# ...

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip        0
# snow          0
# snow_depth    0
# temp_max      0
# temp_min      0
# dtype: int64

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1960-04-01    0.03   0.0         0.0      71.0      47.0
# 1960-04-02    1.36   0.0         0.0      71.0      47.0
# 1960-04-03    0.00   0.0         0.0      71.0      47.0
# 1960-04-04    0.00   0.0         0.0      70.0      47.0
# 1960-04-05    1.75   0.0         0.0      48.0      42.0
# ...            ...   ...         ...       ...       ...
# 2023-09-28    0.03   0.0         0.0      72.0      51.0
# 2023-09-29    0.01   0.0         0.0      69.0      61.0
# 2023-09-30    0.00   0.0         0.0      80.0      59.0
# 2023-10-01    0.00   0.0         0.0      83.0      56.0
# 2023-10-02    0.00   0.0         0.0      83.0      56.0
#
# [22661 rows x 5 columns]

# %%
core_weather.index
# Out:
# Index(['1960-04-01', '1960-04-02', '1960-04-03', '1960-04-04', '1960-04-05',
#        '1960-04-06', '1960-04-07', '1960-04-08', '1960-04-09', '1960-04-10',
#        ...
#        '2023-09-23', '2023-09-24', '2023-09-25', '2023-09-26', '2023-09-27',
#        '2023-09-28', '2023-09-29', '2023-09-30', '2023-10-01', '2023-10-02'],
#       dtype='object', name='DATE', length=22661)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['1960-04-01', '1960-04-02', '1960-04-03', '1960-04-04',
#                '1960-04-05', '1960-04-06', '1960-04-07', '1960-04-08',
#                '1960-04-09', '1960-04-10',
#                ...
#                '2023-09-23', '2023-09-24', '2023-09-25', '2023-09-26',
#                '2023-09-27', '2023-09-28', '2023-09-29', '2023-09-30',
#                '2023-10-01', '2023-10-02'],
#               dtype='datetime64[ns]', name='DATE', length=22661, freq=None)

# %%
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip        0
# snow          0
# snow_depth    0
# temp_max      0
# temp_min      0
# dtype: int64

# %% [markdown]
# Visualizing Data

# %%
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["snow"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["snow_depth"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1960    15.89
# 1961     0.00
# 1962    24.06
# 1963    34.96
# 1964    35.97
#         ...
# 2019    40.81
# 2020    49.47
# 2021    34.96
# 2022    40.76
# 2023    25.87
# Name: precip, Length: 64, dtype: float64

# %%
core_weather["target"] = core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1960-04-01    0.03   0.0         0.0      71.0      47.0    71.0
# 1960-04-02    1.36   0.0         0.0      71.0      47.0    71.0
# 1960-04-03    0.00   0.0         0.0      71.0      47.0    70.0
# 1960-04-04    0.00   0.0         0.0      70.0      47.0    48.0
# 1960-04-05    1.75   0.0         0.0      48.0      42.0    52.0
# ...            ...   ...         ...       ...       ...     ...
# 2023-09-28    0.03   0.0         0.0      72.0      51.0    69.0
# 2023-09-29    0.01   0.0         0.0      69.0      61.0    80.0
# 2023-09-30    0.00   0.0         0.0      80.0      59.0    83.0
# 2023-10-01    0.00   0.0         0.0      83.0      56.0    83.0
# 2023-10-02    0.00   0.0         0.0      83.0      56.0     NaN
#
# [22661 rows x 6 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min  target
# DATE
# 1960-04-01    0.03   0.0         0.0      71.0      47.0    71.0
# 1960-04-02    1.36   0.0         0.0      71.0      47.0    71.0
# 1960-04-03    0.00   0.0         0.0      71.0      47.0    70.0
# 1960-04-04    0.00   0.0         0.0      70.0      47.0    48.0
# 1960-04-05    1.75   0.0         0.0      48.0      42.0    52.0
# ...            ...   ...         ...       ...       ...     ...
# 2023-09-27    0.00   0.0         0.0      72.0      54.0    72.0
# 2023-09-28    0.03   0.0         0.0      72.0      51.0    69.0
# 2023-09-29    0.01   0.0         0.0      69.0      61.0    80.0
# 2023-09-30    0.00   0.0         0.0      80.0      59.0    83.0
# 2023-10-01    0.00   0.0         0.0      83.0      56.0    83.0
#
# [22660 rows x 6 columns]

# %% [markdown]
# Applying Ridge resgression for prediction

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
train = core_weather.loc[:"2021-09-25"]

# %%
test = core_weather.loc["2022-9-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
combined = pd.concat([test["target"],pd.Series(predictions, index=test.index)], axis=1)

# %%
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2022-09-01    88.0    86.177860
# 2022-09-02    88.0    85.733729
# 2022-09-03    90.0    87.198887
# 2022-09-04    85.0    88.575535
# 2022-09-05    88.0    85.151305
# ...            ...          ...
# 2023-09-27    72.0    72.441412
# 2023-09-28    69.0    71.896325
# 2023-09-29    80.0    71.252914
# 2023-09-30    83.0    79.413161
# 2023-10-01    83.0    81.233940
#
# [396 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-1.89002807, -0.15485564, -0.01024765,  0.76972157,  0.16279533])

# %% [markdown]
# Model evaluation

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"],predictions)
# Out:
# 5.708506919002151

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2021-09-25"]
    test = core_weather.loc["2022-9-01":]
    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])
    error = mean_absolute_error(test["target"],predictions)
    combined = pd.concat([test["target"],pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
error, combined = create_predictions(predictors, core_weather, reg)

# %%
error
# Out:
# 5.708506919002151
